# %%
import pandas as pd
df = pd.read_html('https://fastestlaps.com/tracks/le-mans-bugatti')
df
# Out:
# [      Rank                      Vehicle              Driver     Time  \
#  0      1.0                  Ducati GP22   Francesco Bagnaia  1:30.45
#  1      2.0                  Ducati GP22         Jack Miller  1:30.52
#  2      3.0         Aprilia RS-GP (2022)     Aleix Espargaró  1:30.61
#  3      4.0         Yamaha YZR-M1 (2022)    Fabio Quartararo  1:30.69
#  4      5.0                  Ducati GP23   Francesco Bagnaia  1:30.70
#  ..     ...                          ...                 ...      ...
#  206  207.0            Nissan GT-R (R35)  Sebastien Bourdais  1:51.37
#  207  208.0            Jaguar F-Type SVR             unknown  1:51.55
#  208  209.0  Porsche 911 Carrera S (991)             unknown  1:51.97
#  209  210.0       Lotus Exige S Roadster  Christophe Tinseau  1:52.09
#  210  211.0  Chevrolet Corvette Stingray             unknown  1:52.16
#
#          PS / KG
#  0         - / -
#  1         - / -
#  2         - / -
#  3         - / -
#  4         - / -
# ...

# %%
df[0]
# Out:
#       Rank                      Vehicle              Driver     Time  \
# 0      1.0                  Ducati GP22   Francesco Bagnaia  1:30.45
# 1      2.0                  Ducati GP22         Jack Miller  1:30.52
# 2      3.0         Aprilia RS-GP (2022)     Aleix Espargaró  1:30.61
# 3      4.0         Yamaha YZR-M1 (2022)    Fabio Quartararo  1:30.69
# 4      5.0                  Ducati GP23   Francesco Bagnaia  1:30.70
# ..     ...                          ...                 ...      ...
# 206  207.0            Nissan GT-R (R35)  Sebastien Bourdais  1:51.37
# 207  208.0            Jaguar F-Type SVR             unknown  1:51.55
# 208  209.0  Porsche 911 Carrera S (991)             unknown  1:51.97
# 209  210.0       Lotus Exige S Roadster  Christophe Tinseau  1:52.09
# 210  211.0  Chevrolet Corvette Stingray             unknown  1:52.16
#
#         PS / KG
# 0         - / -
# 1         - / -
# 2         - / -
# 3         - / -
# 4         - / -
# ..          ...
# ...
