# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}

questionlist = []

def getQuestions(tag, page):
    url = f'https://stackoverflow.com/questions/tagged/{tag}?tab=Active&page={page}&pagesize=50'
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, 'html.parser')
    questions = soup.find_all('div', {'class': 'question-summary'})
    for item in questions:
        question = {
        'tag': tag,    
        'title': item.find('a', {'class': 'question-hyperlink'}).text,
        'link': 'https://stackoverflow.com' + item.find('a', {'class': 'question-hyperlink'})['href'],
        'votes': int(item.find('span', {'class': 'vote-count-post'}).text),
        'date': item.find('span', {'class': 'relativetime'})['title'],
        }
        questionlist.append(question)
    return

for x in range(1,3):
    getQuestions('python', x)
    getQuestions('flask', x)

df = pd.DataFrame(questionlist)
df
# Out:
#         tag                                              title  \
# 0    python   How to get the euler angle of the target itself?
# 1    python  how to get data from a SQlite databse in pytho...
# 2    python  Python ModuleNotFoundError: No module named 's...
# 3    python  How can I make this tiny Python 2.7 complex nu...
# 4    python  How to make it so if any variable in a list is...
# ..      ...                                                ...
# 195   flask  Flask - Calling a function with flask [duplicate]
# 196   flask  URL routing conflicts for static files in Flas...
# 197   flask    Upload Files and a String in same Flask Request
# 198   flask  How to tell jinja about files in static sub-di...
# 199   flask  Using Python Flask to change the colour of an ...
#
#                                                   link  votes  \
# 0    https://stackoverflow.com/questions/70797301/h...      0
# 1    https://stackoverflow.com/questions/70797295/h...      0
# 2    https://stackoverflow.com/questions/70797176/p...      0
# 3    https://stackoverflow.com/questions/70797185/h...      0
# 4    https://stackoverflow.com/questions/70796382/h...      1
# ..                                                 ...    ...
# 195  https://stackoverflow.com/questions/70761170/f...      0
# 196  https://stackoverflow.com/questions/17135006/u...      7
# 197  https://stackoverflow.com/questions/70754829/u...      0
# 198  https://stackoverflow.com/questions/70754761/h...     -1
# 199  https://stackoverflow.com/questions/70760450/u...     -1
#
#                      date
# 0    2022-01-21 06:35:35Z
# 1    2022-01-21 06:34:56Z
# 2    2022-01-21 06:34:05Z
# 3    2022-01-21 06:34:05Z
# 4    2022-01-21 06:33:51Z
# ..                    ...
# 195  2022-01-18 19:36:08Z
# 196  2022-01-18 19:29:38Z
# 197  2022-01-18 19:24:35Z
# 198  2022-01-18 19:21:25Z
# 199  2022-01-18 19:13:47Z
#
# [200 rows x 5 columns]
