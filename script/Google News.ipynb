# %%
from requests_html import HTMLSession

url = 'https://news.google.com/rss/search?q=metaverse'

s = HTMLSession()

r = s.get(url)

for title in r.html.find('title'):
    print(title.text)
    print('-'*60)
# Out:
# "metaverse" - Google News
# ------------------------------------------------------------
# SoftBank-backed startup Improbable outlines plan for metaverse to rival Microsoft, Meta - CNBC
# ------------------------------------------------------------
# The Metaverse Hype Died Down. Where Does That Leave Colleges That Invested In It? - EdSurge
# ------------------------------------------------------------
# Study finds Metaverse could aid in combating global warming | Technology News – India TV - India TV News
# ------------------------------------------------------------
# Metaverse may help tackle global warming: Study - Telangana Today
# ------------------------------------------------------------
# 7 sectors on which web3.0 and metaverse are creating an impact - The Financial Express
# ------------------------------------------------------------
# Popular Metaverse Development Languages Amid Web3 Developers - Analytics Insight
# ...
